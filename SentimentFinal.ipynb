# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import numpy as np
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import os
import matplotlib.pyplot as plt
# %matplotlib inline
# For Sentiment Analysis
import nltk
nltk.downloader.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# **Store Data, Time and Headlines**

# %%
n = 3

stock = input("Enter the stock: ")
print(stock)
stock = stock.upper()
print(stock)
tickers=[]
tickers.append(stock)
finwiz_url = 'https://finviz.com/quote.ashx?t='
news_tables = {}
for ticker in tickers:
    url = finwiz_url + ticker
    req = Request(url=url,headers={'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:20.0) Gecko/20100101 Firefox/20.0'}) 
    result = urlopen(req)    
    # Place the contents of the file in html page named 'html'
    html = BeautifulSoup(result)
    news_table = html.find(id='news-table')
    news_tables[ticker] = news_table
# Out:
# aapl
# AAPL

# %% [markdown]
# **Print the above column(just for debugging purposes)**

# %%
try:
  for ticker in tickers:
    df = news_tables[ticker]
    df_tr = df.findAll('tr')
    for i, table_row in enumerate(df_tr):
      # Read the text of the element 'a' 
      a_text = table_row.a.text
      # Read the text of the element 'td' 
      td_text = table_row.td.text
      #Clean data using strip()
      td_text = td_text.strip()
      print(a_text)
      print(td_text)

      if i == n-1:
        break
except KeyError:
  pass
# Out:
# Stocks trade mixed at the open as investors await Fed rate hike decision
# Mar-22-23 10:02AM
# $10,000 Invested In These Growth Stocks Could Make You a Fortune Over the Next 10 Years
# 09:45AM
# Is Now the Time to Buy Solana?
# 08:50AM

# %% [markdown]
# **Make list of data**

# %%
parsed_news = []
for file_name, news_table in news_tables.items():
    try:
      for x in news_table.findAll('tr'):
          text = x.a.get_text()
          date_scrape = x.td.text.split()
          
          if len(date_scrape) == 1:
            time = date_scrape[0]
              
          # else load 'date' as the 1st element and 'time' as the second    
          else:
            date = date_scrape[0]
            time = date_scrape[1]
          # Extract the ticker from the file name, get the string up to the 1st '_'  
          ticker = file_name.split('_')[0]
          
          parsed_news.append([ticker, date, time, text])
      
    except KeyError:
      pass    
parsed_news
# Out:
# [['AAPL',
#   'Mar-22-23',
#   '10:02AM',
#   'Stocks trade mixed at the open as investors await Fed rate hike decision'],
#  ['AAPL',
#   'Mar-22-23',
#   '09:45AM',
#   '$10,000 Invested In These Growth Stocks Could Make You a Fortune Over the Next 10 Years'],
#  ['AAPL', 'Mar-22-23', '08:50AM', 'Is Now the Time to Buy Solana?'],
#  ['AAPL',
#   'Mar-22-23',
#   '06:00AM',
#   '3 things to watch in TikTok CEO testimony to Congress'],
#  ['AAPL',
#   'Mar-22-23',
#   '05:45AM',
#   'Nasdaq Bear Market: 1 Key Reason Apple Has Avoided Major Job Cuts'],
#  ['AAPL',
#   'Mar-22-23',
#   '05:30AM',
#   'Apple, Microsoft Dominate U.S. Markets After FAANG Trade Fizzles'],
#  ['AAPL',
#   'Mar-22-23',
#   '05:20AM',
#   '3 Blue-Chip Dividend Stocks That Generate Gobs of Shareholder Value'],
#  ['AAPL', 'Mar-21-23', '08:00PM', 'Apple Lobbies India Hard on Labor Law'],
#  ['AAPL', 'Mar-21-23', '02:08PM', 'Apple Stock Gears Up for Major Breakout'],
#  ['AAPL',
#   'Mar-21-23',
#   '01:06PM',
#   "Apple's Latest Moves To Abandon China Require A Big Lift: Changing India's Rules"],
#  ['AAPL', 'Mar-21-23', '12:41PM', 'Apple Shares Are at a Pivot Point'],
#  ['AAPL',
#   'Mar-21-23',
#   '12:34PM',
#   "Netflix's (NFLX) Expanding Games Portfolio Aids Prospects"],
#  ['AAPL',
#   'Mar-21-23',
#   '11:00AM',
#   "'Invite me to your funeral': Jim Cramer makes a bold call on the Nasdaq  and even billionaire Elon Musk had to respond. Here are 3 ways to bet on that conviction"],
#  ['AAPL',
#   'Mar-21-23',
#   '10:17AM',
#   "The Hidden Winner of Samsung's OLED-TV Strategy Shift"],
#  ['AAPL', 'Mar-21-23', '10:07AM', '549 Billion Reasons to Buy Apple Stock'],
#  ['AAPL',
#   'Mar-21-23',
#   '10:04AM',
#   'Alphabet (GOOGL) Bolsters Google Maps With Immersive View'],
#  ['AAPL',
#   'Mar-21-23',
#   '10:00AM',
#   "Microsoft's Pursuit of Market Dominance: Who's Next After Alphabet?"],
#  ['AAPL', 'Mar-21-23', '09:21AM', 'Meta Stock: Bull vs. Bear'],
#  ['AAPL',
#   'Mar-21-23',
#   '08:47AM',
#   'Apple Seeks India Labor Reform to Diversify Beyond China'],
#  ['AAPL',
#   'Mar-21-23',
#   '07:22AM',
#   'Apple has avoided mass layoffs thanks to 3 prudent business moves'],
#  ['AAPL',
#   'Mar-21-23',
#   '05:06AM',
#   'Battle of Dividend Stocks: Microsoft vs. Apple'],
#  ['AAPL',
#   'Mar-20-23',
#   '08:00PM',
#   'Microsoft Says It Wants To Launch App Store Rival'],
#  ['AAPL',
#   'Mar-20-23',
#   '05:45PM',
#   'Apple (AAPL) Outpaces Stock Market Gains: What You Should Know'],
#  ['AAPL',
#   'Mar-20-23',
#   '09:00AM',
#   "Microsoft Could Become the World's First $5 Trillion Company By 2030"],
#  ['AAPL',
#   'Mar-20-23',
#   '07:56AM',
#   'RPC and Thor Industries have been highlighted as Zacks Bull and Bear of the Day'],
#  ['AAPL',
#   'Mar-20-23',
#   '07:05AM',
#   'Technical Assessment: Bearish in the Intermediate-Term'],
#  ['AAPL',
#   'Mar-20-23',
#   '01:00AM',
#   'Microsoft plans mobile games app store to rival Apple and Google'],
#  ['AAPL',
#   'Mar-19-23',
#   '01:15PM',
#   'Why Apple, Warner Bros. Discovery, and AMD Are No-Brainer Buys Right Now'],
#  ['AAPL',
#   'Mar-19-23',
#   '10:30AM',
#   'You Can Save $100 or More on These 10 Costco Buys Now'],
#  ['AAPL',
#   'Mar-19-23',
#   '10:15AM',
#   'The Problem With Your Dying AirPods and Other Bluetooth Earbuds'],
#  ['AAPL',
#   'Mar-19-23',
#   '10:00AM',
#   "Is it safe to buy now or is this just a 'dead cat bounce'? Morgan Stanley's stock chief says you should sell any rallies  but here are 3 stocks the big bank still likes"],
#  ['AAPL', 'Mar-19-23', '07:03AM', 'Better Bear Market Stock: AT&T vs. Apple'],
#  ['AAPL',
#   'Mar-19-23',
#   '05:52AM',
#   "If You Invested $10,000 in Apple When Warren Buffett First Bought the Stock, Here's How Much You'd Have Now"],
#  ['AAPL',
#   'Mar-19-23',
#   '05:30AM',
#   '3 Dividend Stocks That Are Bursting With Free Cash Flow'],
#  ['AAPL',
#   'Mar-18-23',
#   '06:15PM',
#   'Graham Stephan Stock Portfolio: 10 Stock Picks'],
#  ['AAPL',
#   'Mar-18-23',
#   '04:50PM',
#   '15 Most Promising Long-Term Stocks According to Analysts'],
#  ['AAPL',
#   'Mar-18-23',
#   '03:00PM',
#   'Target, Amazon and 4 More Retailers That Will Reward You for Turning in Your Old Stuff'],
#  ['AAPL',
#   'Mar-18-23',
#   '12:28PM',
#   'How Big Tech Became the New Defensive Stock Play'],
#  ['AAPL',
#   'Mar-18-23',
#   '08:59AM',
#   'Want Passive Income in a Bear Market? 3 Stocks Warren Buffett Bought'],
#  ['AAPL',
#   'Mar-18-23',
#   '05:45AM',
#   'Where to Invest in Artificial Intelligence Stocks Today'],
#  ['AAPL',
#   'Mar-18-23',
#   '03:12AM',
#   'Zedge, Inc. (AMEX:ZDGE) Q2 2023 Earnings Call Transcript'],
#  ['AAPL', 'Mar-17-23', '06:50PM', 'Apple Pay vs. Google Wallet'],
#  ['AAPL', 'Mar-17-23', '06:49PM', 'Weekly Roundup'],
#  ['AAPL', 'Mar-17-23', '06:30PM', '6 Useless Subscriptions To Cancel in 2023'],
#  ['AAPL', 'Mar-17-23', '05:00PM', 'Better Growth Stock: Nvidia vs. Apple'],
#  ['AAPL',
#   'Mar-17-23',
#   '04:54PM',
#   'Best FAANG Stock to Buy: Facebook vs. Amazon vs. Apple vs. Netflix vs. Google'],
#  ['AAPL',
#   'Mar-17-23',
#   '02:22PM',
#   'The 10 best free checking accounts of March 2023'],
#  ['AAPL',
#   'Mar-17-23',
#   '01:25PM',
#   'Why Bank Blowups Have Been Good News for Apple Stock and the Rest of Big Tech'],
#  ['AAPL',
#   'Mar-17-23',
#   '11:59AM',
#   'Why the Banking Crisis Has Been Good News for Apple Stock and the Rest of Big Tech'],
#  ['AAPL',
#   'Mar-17-23',
#   '11:59AM',
#   'Why Bank Troubles Have Been Good News for Apple Stock and the Rest of Big Tech'],
#  ['AAPL',
#   'Mar-17-23',
#   '09:41AM',
#   'Apple, Microsoft Dominance on\xa0Tech-Stock indexes\xa0Grows in Benchmark Overhaul'],
#  ['AAPL',
#   'Mar-17-23',
#   '09:25AM',
#   '2 Stocks That Could Join Apple, Alphabet, and Microsoft in the $1 Trillion Club'],
#  ['AAPL', 'Mar-17-23', '08:00AM', 'Better Buy: Apple vs. Disney'],
#  ['AAPL', 'Mar-17-23', '07:35AM', '12 Most Buzzing Stocks To Buy Now'],
#  ['AAPL',
#   'Mar-17-23',
#   '07:01AM',
#   'Recent uptick might appease Apple Inc. (NASDAQ:AAPL) institutional owners after losing 4.4% over the past year'],
#  ['AAPL',
#   'Mar-17-23',
#   '05:54AM',
#   'Stock Market Rallies As 11 Bank Giants Aid First Republic; Apple, Microsoft Flash Buy Signals'],
#  ['AAPL',
#   'Mar-17-23',
#   '05:45AM',
#   'Got $3,000? These Stocks Could Double Your Money by 2030'],
#  ['AAPL', 'Mar-17-23', '05:32AM', 'Stock Market Sell-Off: Is Apple a Buy?'],
#  ['AAPL',
#   'Mar-17-23',
#   '05:06AM',
#   "94% of Warren Buffett's $321 Billion Portfolio Is Invested in Only 4 Sectors"],
#  ['AAPL', 'Mar-16-23', '07:22PM', "Is This PayPal's Biggest Threat?"],
#  ['AAPL',
#   'Mar-16-23',
#   '06:30PM',
#   '3 Big Tech Stocks are Holding Up the Entire Market'],
#  ['AAPL',
#   'Mar-16-23',
#   '05:21PM',
#   'Stock Market Rebounds As 11 Bank Giants Aid First Republic; Apple, Microsoft Flash Buy Signals'],
#  ['AAPL',
#   'Mar-16-23',
#   '04:21PM',
#   'Lockdown Logic Rears Its Head in Stock Rally Running on Nerves'],
#  ['AAPL',
#   'Mar-16-23',
#   '01:23PM',
#   'The Big Tech Layoffs Malaise Reveals A Deeper Truth'],
#  ['AAPL',
#   'Mar-16-23',
#   '11:00AM',
#   'The Most Outrageous CEO Salaries and Perks'],
#  ['AAPL',
#   'Mar-16-23',
#   '10:38AM',
#   '10 Stocks ChatGPT Says Will Make Me Rich in 10 Years'],
#  ['AAPL',
#   'Mar-16-23',
#   '09:37AM',
#   '3 ETFs That Can Supercharge Your Retirement Savings'],
#  ['AAPL', 'Mar-16-23', '09:00AM', 'Microsoft Stock: Bear vs. Bull'],
#  ['AAPL',
#   'Mar-16-23',
#   '09:00AM',
#   'If You Invested $10,000 in Apple Stock in 2013, This Is How Much You Would Have Today'],
#  ['AAPL',
#   'Mar-16-23',
#   '08:02AM',
#   "Apple's Key Supplier Wins Airpod Order  Plans To Build $200M Plant In India"],
#  ['AAPL',
#   'Mar-16-23',
#   '07:57AM',
#   'Dina Srinivasan: exposing the monopoly power of Facebook and Google'],
#  ['AAPL',
#   'Mar-16-23',
#   '07:43AM',
#   "3 No-Brainer Stocks I'd Buy Right Now Without Hesitation"],
#  ['AAPL',
#   'Mar-16-23',
#   '06:45AM',
#   '2 Unstoppable AI Stocks to Buy for the Next Decade'],
#  ['AAPL',
#   'Mar-16-23',
#   '06:37AM',
#   "Warren Buffett Stocks: What's Inside Berkshire Hathaway's Portfolio?"],
#  ['AAPL', 'Mar-16-23', '06:00AM', 'Q2 2023 Zedge Inc Earnings Call'],
#  ['AAPL',
#   'Mar-16-23',
#   '05:50AM',
#   'The 3 Stocks Warren Buffett Is Most Likely Buying Right Now in Addition to Occidental'],
#  ['AAPL',
#   'Mar-16-23',
#   '01:00AM',
#   'Technology sector set to lose more  titans in reclassification'],
#  ['AAPL',
#   'Mar-15-23',
#   '11:04PM',
#   'Exclusive-Apple supplier Foxconn wins AirPod order, plans $200 million factory in India - source'],
#  ['AAPL',
#   'Mar-15-23',
#   '04:15PM',
#   'Apple iPhone manufacturer FoxConn warns on waning electronics demand, reliance on China'],
#  ['AAPL',
#   'Mar-15-23',
#   '01:39PM',
#   'Microsoft, Apple and Meta outperform as investors seek safety from SVB chaos in megacap tech stocks'],
#  ['AAPL',
#   'Mar-15-23',
#   '12:54PM',
#   'Silicon Valleys startup scene is safe. At least for now.'],
#  ['AAPL',
#   'Mar-15-23',
#   '12:43PM',
#   'Apple Supplier Foxconn Plans to Rely Less on China for Revenue'],
#  ['AAPL',
#   'Mar-15-23',
#   '12:13PM',
#   "Apple Eases On Bonus & Hiring, Federal Reserve Mulls Tougher Rules After SVB Failure, Meta-Backed Undersea Cable Project Delayed By China: Today's Top Stories"],
#  ['AAPL',
#   'Mar-15-23',
#   '10:58AM',
#   'Apple Joins Cost Cut Bandwagon, Eases On Bonus, Hiring, Triggers Employee Fears Of Layoffs'],
#  ['AAPL',
#   'Mar-15-23',
#   '09:45AM',
#   'A Bull Market Is Coming: 3 Big Reasons to Buy Apple Stock Right Now'],
#  ['AAPL', 'Mar-15-23', '09:00AM', 'Apple Stock: Bear vs. Bull'],
#  ['AAPL',
#   'Mar-15-23',
#   '08:45AM',
#   'Apple Hasnt Made Layoffs. Why Its Still More Efficient Than Meta.'],
#  ['AAPL',
#   'Mar-15-23',
#   '08:00AM',
#   '2 Roaring Stocks to Hold for the Next 20 Years'],
#  ['AAPL',
#   'Mar-15-23',
#   '06:46AM',
#   'IPhone Maker Hon Hai Expects Flat 2023 as It Builds EV Push'],
#  ['AAPL',
#   'Mar-15-23',
#   '06:26AM',
#   'Stocks Slump, Charles Schwab Support, Credit Suisse Wobbles, Foxconn Caution, Adobe Earnings - Five Things To Know'],
#  ['AAPL',
#   'Mar-15-23',
#   '05:30AM',
#   'Inside the Lucrativeand SecretiveBusiness of iPhone Trade-Ins'],
#  ['AAPL',
#   'Mar-15-23',
#   '05:06AM',
#   '3 Stocks Retail Investors Are Buying Hand Over Fist'],
#  ['AAPL',
#   'Mar-15-23',
#   '02:43AM',
#   'UPDATE 3-Apple supplier Foxconn steps up investment outside China, as consumer electronics demand dips'],
#  ['AAPL',
#   'Mar-15-23',
#   '12:06AM',
#   'UPDATE 1-India plans new security testing for smartphones, crackdown on pre-installed apps'],
#  ['AAPL',
#   'Mar-14-23',
#   '07:28PM',
#   'Apple will reportedly postpone some bonuses until later in the year'],
#  ['AAPL',
#   'Mar-14-23',
#   '04:07PM',
#   'California court upholds Prop. 22 ruling on gig workers, Apple delays bonuses'],
#  ['AAPL',
#   'Mar-14-23',
#   '02:45PM',
#   'Apple plans to delay bonuses for some employees: report'],
#  ['AAPL',
#   'Mar-14-23',
#   '02:11PM',
#   'Silicon Valley Bank fallout likely to hit big tech, strategist says'],
#  ['AAPL',
#   'Mar-14-23',
#   '01:53PM',
#   'Apple Delays Bonuses for Some and\xa0Limits Hiring in Latest Cost-Cutting Effort'],
#  ['AAPL',
#   'Mar-14-23',
#   '01:31PM',
#   "You'll Never Guess the Top-Performing Stock of the Last 20 Years"]]

# %% [markdown]
# **Apply Sentiment Analysis**

# %%
vader_analysis = SentimentIntensityAnalyzer()
columns = ['Ticker', 'Date', 'Time', 'Headline']

parsed_and_scored_news = pd.DataFrame(parsed_news, columns=columns)

scores = parsed_and_scored_news['Headline'].apply(vader_analysis.polarity_scores).tolist()

scores_df = pd.DataFrame(scores)

parsed_and_scored_news = parsed_and_scored_news.join(scores_df, rsuffix='_right')

parsed_and_scored_news['Date'] = pd.to_datetime(parsed_and_scored_news.Date).dt.date


parsed_and_scored_news = parsed_and_scored_news.set_index('Ticker')

parsed_and_scored_news
# Out:
#               Date     Time  \
# Ticker
# AAPL    2023-03-22  10:02AM
# AAPL    2023-03-22  09:45AM
# AAPL    2023-03-22  08:50AM
# AAPL    2023-03-22  06:00AM
# AAPL    2023-03-22  05:45AM
# ...            ...      ...
# AAPL    2023-03-14  04:07PM
# AAPL    2023-03-14  02:45PM
# AAPL    2023-03-14  02:11PM
# AAPL    2023-03-14  01:53PM
# AAPL    2023-03-14  01:31PM
#
#                                                  Headline    neg    neu  \
# Ticker
# AAPL    Stocks trade mixed at the open as investors aw...  0.000  0.896
# AAPL    $10,000 Invested In These Growth Stocks Could ...  0.000  0.843
# AAPL                       Is Now the Time to Buy Solana?  0.000  1.000
# AAPL    3 things to watch in TikTok CEO testimony to C...  0.000  1.000
# AAPL    Nasdaq Bear Market: 1 Key Reason Apple Has Avo...  0.338  0.662
# ...                                                   ...    ...    ...
# AAPL    California court upholds Prop. 22 ruling on gi...  0.000  0.753
# AAPL    Apple plans to delay bonuses for some employee...  0.178  0.543
# AAPL    Silicon Valley Bank fallout likely to hit big ...  0.000  1.000
# AAPL    Apple Delays Bonuses for Some and Limits Hirin...  0.000  0.753
# AAPL    You'll Never Guess the Top-Performing Stock of...  0.000  1.000
#
#           pos  compound
# Ticker
# AAPL    0.104    0.1027
# AAPL    0.157    0.3818
# AAPL    0.000    0.0000
# AAPL    0.000    0.0000
# AAPL    0.000   -0.5574
# ...       ...       ...
# AAPL    0.247    0.5574
# AAPL    0.279    0.3182
# AAPL    0.000    0.0000
# AAPL    0.247    0.5574
# AAPL    0.000    0.0000
#
# [100 rows x 7 columns]

# %% [markdown]
# **Display the Final Result**

# %%
df = parsed_and_scored_news
df = df.drop(columns = ['Headline','Date','Time', 'neg', 'pos', 'neu'])
mean = round(df.mean(), 4)
print(df)
print("Final Sentiment: ", mean)
# a positive sentiment, compound ≥ 0.05
# a negative sentiment, compound ≤ -0.05
# a neutral sentiment, the compound is between [-0.05, 0.05]
# Out:
#         compound
# Ticker
# AAPL      0.1027
# AAPL      0.3818
# AAPL      0.0000
# AAPL      0.0000
# AAPL     -0.5574
# ...          ...
# AAPL      0.5574
# AAPL      0.3182
# AAPL      0.0000
# AAPL      0.5574
# AAPL      0.0000
#
# [100 rows x 1 columns]
# Final Sentiment:  compound    0.1229
# dtype: float64
